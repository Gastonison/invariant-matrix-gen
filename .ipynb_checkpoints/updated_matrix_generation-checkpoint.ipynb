# %%
import os
import subprocess
import commands
import time
from tqdm import tqdm_notebook.tqdm

def generate_sms(mat, dic):
    items = sorted(dic.items())
    result_string = ""
    for key, val in items:
        if val != 0:
            result_string += "{} {} {}\n".format(key[0]+1, key[1]+1, val)
    result_string += "0 0 0\n"
    create_sms_file(mat, result_string)

def create_sms_file(mat, result_string):
    sms_file= open("spasm/bench/bivariant_matrix.sms","w+")
    sms_file.write('{} {} M\n'.format(mat.nrows(), mat.ncols()))
    sms_file.write(result_string)
    return sms_file

def run_spasm_rank():    
    spasm_script = 'cat spasm/bench/bivariant_matrix.sms | ./spasm/bench/rank_hybrid'
    response = commands.getstatusoutput(spasm_script)
    rank = response[1].split("s rank = ",1)[1]
    return rank

# %%
n = 0
p = 0
result_matrix = matrix
enumeration_dictionary = {}
result_dictionary = {}
result_array = []
eqn_row = 0

# Returns matrix / dictionary generated by relations
def generate_matrix(n_val, p_val):
    #sets global variables
    global n, p, result_matrix, result_dictionary, eqn_row
    n = n_val
    p = p_val
    eqn_row = 0
    generate_enumerated_permutation()
    result_matrix = generate_initial_matrix()
    result_dictionary = generate_initial_dictionary()
    
    populate_matrix()
    return result_matrix, result_dictionary


# Identifies permutation    
# def enumerate_permutation(perm):
#     sorted_perm=sorted(perm)
#     size=len(perm)
#     c=sum(binomial(p-1+i,i+1) for i in range(size))
#     return c-sum(binomial(p-2+size-sorted_perm[i]-i,size-i) for i in range(size))

def generate_enumerated_permutation():
    timerValue = time.time()


    global enumeration_dictionary
#     c=sum(binomial(p-1+i,i+1) for i in range(n))
#     c-sum(binomial(p-2+n-a[i]-i,n-i) for i in range(n)) (set tuple value to this, may be unnecessary)
    count = 0
    for aset in Subsets(p-1+n,n):
        alist=list(aset)
        alist.sort()
        a=[alist[i]-i-1 for i in range(n)]
        enumeration_dictionary[tuple(a)] = count
        count += 1
    print("Populating enumerated list took {} seconds".format(time.time() % timerValue))
        
def enumerate_permutation(perm):
    return enumeration_dictionary[tuple(sorted(perm))]


# Generates initial values for the Matrix
def generate_initial_matrix():
    nvars=binomial(p-1+n,n)
    neqs=1+sum(binomial(p-1+k,k)*binomial(p-1+n-k,n-k) for k in [2]) 
    M=matrix(QQ,neqs,nvars,sparse=True)
    eqn=0;j=enumerate_permutation([0 for i in [1..n]]);M[eqn,j]=1
    return M

# Generates initial values for the Dictionary
def generate_initial_dictionary():
    return {(0,0):1}

# Sets column values
def calculate_column_values(a, b, k):
    for i in range(k):
        a_generated = [(a[i1]-a[i])%p for i1 in range(k)]
        a_generated[i] = a[i]
        j=enumerate_permutation(a_generated+b)

        #matrix
#         result_matrix[eqn_row, j]=result_matrix[eqn_row,j]-1/a.count(a[i])
        
        #dictionary
        if (eqn_row, j) in result_dictionary:
            result_dictionary[(eqn_row,j)] = result_dictionary[(eqn_row, j)]-1/a.count(a[i])
        else:
            result_dictionary[(eqn_row,j)] = -1/a.count(a[i])
            
# Iterates through all permutations of a, b
def iterate_permutations(k, handle_permutation):
    global eqn_row
    timerValue = time.time()
    for aset in tqdm_notebook(Subsets(p-1+k,k)): 
#     for aset in Subsets(p-1+k,k): 
        alist=list(aset)
        alist.sort()
        a=[alist[i]-i-1 for i in range(k)]
        for bset in Subsets(p-1+n-k,n-k):
            eqn_row=eqn_row+1
            blist=list(bset)
            blist.sort()
            b=[blist[i]-i-1 for i in range(n-k)]
            handle_permutation(a, b, k)
    print("Generating Matrix took {} seconds".format(time.time() % timerValue))
# Handles what to do with each iterated permutation
def evaluate_permutation(a, b, k):
    j=enumerate_permutation(a+b)
    result_matrix[eqn_row,j]=1
    result_dictionary[(eqn_row, j)] = 1
    calculate_column_values(a, b, k)

# Starts process of populating matrix / dictionary
def populate_matrix(): 
    for k in [2]:
        iterate_permutations(2, evaluate_permutation)

# %%
for i in [2..500]:
    timerValue = time.time()
    generated_matrix, generated_dictionary = generate_matrix(5,i)

    #     matrix solution
#     rank = generated_matrix.rank()

    #     dictionary solution
    generate_sms(generated_matrix, generated_dictionary)
    rank = run_spasm_rank()

    result = binomial(p-1+n, n)-int(rank)

    print("Computing rank + generating matrix took: {} seconds".format(time.time() % timerValue))
    print("{} {}".format(i, result))
# Out:
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/tqdm/__init__.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   TqdmDeprecationWarning)
# HBox(children=(IntProgress(value=0, max=3), HTML(value=u'')))
# Computing rank + generating matrix took: 0.095027923584 seconds
# 2 0
# HBox(children=(IntProgress(value=0, max=6), HTML(value=u'')))
# Computing rank + generating matrix took: 0.0684609413147 seconds
# 3 0
# HBox(children=(IntProgress(value=0, max=10), HTML(value=u'')))
# Computing rank + generating matrix took: 0.0682210922241 seconds
# 4 0
# HBox(children=(IntProgress(value=0, max=15), HTML(value=u'')))
# Computing rank + generating matrix took: 0.112133979797 seconds
# 5 0
# HBox(children=(IntProgress(value=0, max=21), HTML(value=u'')))
# Computing rank + generating matrix took: 0.189298868179 seconds
# 6 0
# HBox(children=(IntProgress(value=0, max=28), HTML(value=u'')))
# Computing rank + generating matrix took: 0.21048283577 seconds
# 7 0
# HBox(children=(IntProgress(value=0, max=36), HTML(value=u'')))
# Computing rank + generating matrix took: 0.347651004791 seconds
# 8 0
# HBox(children=(IntProgress(value=0, max=45), HTML(value=u'')))
# Computing rank + generating matrix took: 0.546671867371 seconds
# 9 0
# HBox(children=(IntProgress(value=0, max=55), HTML(value=u'')))
# Computing rank + generating matrix took: 0.852352142334 seconds
# 10 0
# HBox(children=(IntProgress(value=0, max=66), HTML(value=u'')))
# Computing rank + generating matrix took: 1.26591014862 seconds
# 11 0
# HBox(children=(IntProgress(value=0, max=78), HTML(value=u'')))
# Computing rank + generating matrix took: 1.96335101128 seconds
# 12 0
# HBox(children=(IntProgress(value=0, max=91), HTML(value=u'')))
# Computing rank + generating matrix took: 2.97866988182 seconds
# 13 0
# HBox(children=(IntProgress(value=0, max=105), HTML(value=u'')))
# Computing rank + generating matrix took: 4.2451198101 seconds
# 14 0
# HBox(children=(IntProgress(value=0, max=120), HTML(value=u'')))
# Computing rank + generating matrix took: 6.15720391273 seconds
# 15 0
# HBox(children=(IntProgress(value=0, max=136), HTML(value=u'')))
# Computing rank + generating matrix took: 8.33664798737 seconds
# 16 0
# HBox(children=(IntProgress(value=0, max=153), HTML(value=u'')))
# Computing rank + generating matrix took: 12.5072238445 seconds
# 17 0
# HBox(children=(IntProgress(value=0, max=171), HTML(value=u'')))
# Computing rank + generating matrix took: 16.779184103 seconds
# 18 0
# HBox(children=(IntProgress(value=0, max=190), HTML(value=u'')))
# Computing rank + generating matrix took: 18.189868927 seconds
# 19 0
# HBox(children=(IntProgress(value=0, max=210), HTML(value=u'')))
# Computing rank + generating matrix took: 23.7629351616 seconds
# 20 0
# HBox(children=(IntProgress(value=0, max=231), HTML(value=u'')))
# Computing rank + generating matrix took: 29.8775048256 seconds
# 21 0
# HBox(children=(IntProgress(value=0, max=253), HTML(value=u'')))
# Computing rank + generating matrix took: 37.3330180645 seconds
# 22 0
# HBox(children=(IntProgress(value=0, max=276), HTML(value=u'')))
